# %% [markdown]
# # Naive Bayes
# ## News Data

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
from sklearn.metrics import accuracy_score

import nltk;
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download([
    "names",
    "stopwords",
    "state_union",
    "twitter_samples",
    "movie_reviews",
    "averaged_perceptron_tagger",
    "vader_lexicon",
    "punkt",])

import string
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/mariaagustinazuckerberg/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/mariaagustinazuckerberg/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/mariaagustinazuckerberg/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mariaagustinazuckerberg/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package names to
# [nltk_data]     /Users/mariaagustinazuckerberg/nltk_data...
# [nltk_data]   Package names is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mariaagustinazuckerberg/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package state_union to
# [nltk_data]     /Users/mariaagustinazuckerberg/nltk_data...
# [nltk_data]   Package state_union is already up-to-date!
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /Users/mariaagustinazuckerberg/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /Users/mariaagustinazuckerberg/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/mariaagustinazuckerberg/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/mariaagustinazuckerberg/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/mariaagustinazuckerberg/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_csv('../../data/01-modified-data/clean_sentiment_analysis.csv')

print(df.shape)

df = df.rename(columns={'ibm_label': 'label', 'ibm_content': 'text', 'ibm_score': 'sentiment'})

df
# Out:
# (53, 6)
#                 name    category  sentiment     label        date  \
# 0              Wired  technology    -0.5961  negative  2023-10-27
# 1          The Verge  technology    -0.8783  negative  2023-10-27
# 2       Ars Technica  technology     0.2886  positive  2023-10-31
# 3   Business Insider    business     0.6452  positive  2023-10-22
# 4       The Next Web  technology     0.6209  positive  2023-10-24
# 5       The Next Web  technology     0.9080  positive  2023-10-23
# 6   Business Insider    business    -0.6760  negative  2023-10-18
# 7           Engadget  technology     0.0000   neutral  2023-10-22
# 8   Business Insider    business     0.6035  positive  2023-10-29
# 9               Time     general     0.0000   neutral  2023-10-19
# 10              Time     general     0.0000   neutral  2023-10-19
# 11      Ars Technica  technology     0.8393  positive  2023-10-16
# 12          CBS News     general    -0.6290  negative  2023-10-23
# 13   Next Big Future     science     0.0000   neutral  2023-10-25
# 14     New Scientist     science     0.6051  positive  2023-10-31
# 15          CBS News     general    -0.7609  negative  2023-10-17
# 16           Fortune    business    -0.8252  negative  2023-10-19
# 17           Fortune    business     0.0000   neutral  2023-10-31
# 18     New Scientist     science     0.8984  positive  2023-10-24
# 19         TechRadar  technology     0.0000   neutral  2023-10-16
# 20          CBS News     general     0.6510  positive  2023-10-17
# 21          Newsweek     general    -0.9520  negative  2023-10-23
# 22          ABC News     general     0.0000   neutral  2023-10-31
# 23           Fortune    business    -0.6701  negative  2023-10-31
# 24    Breitbart News     general     0.6588  positive  2023-10-16
# 25    Breitbart News     general     0.0000   neutral  2023-10-19
# 26          ABC News     general     0.6487  positive  2023-11-01
# 27          ABC News     general    -0.8907  negative  2023-10-19
# 28          ABC News     general     0.6301  positive  2023-10-29
# 29     New Scientist     science     0.0000   neutral  2023-10-30
# 30          Newsweek     general     0.4480  positive  2023-10-30
# 31          ABC News     general     0.0000   neutral  2023-10-31
# 32          ABC News     general     0.5985  positive  2023-10-25
# 33          ABC News     general    -0.8907  negative  2023-10-19
# 34          ABC News     general     0.5985  positive  2023-10-25
# 35          ABC News     general     0.6487  positive  2023-11-01
# 36          ABC News     general     0.6301  positive  2023-10-29
# 37              Time     general    -0.3817  negative  2023-10-20
# 38          ABC News     general     0.5985  positive  2023-10-25
# 39          ABC News     general     0.0000   neutral  2023-10-17
# 40    Breitbart News     general     0.0000   neutral  2023-10-17
# 41      Ars Technica  technology    -0.7175  negative  2023-10-25
# 42    Breitbart News     general     0.3935  positive  2023-10-31
# 43    Breitbart News     general     0.0000   neutral  2023-10-23
# 44          Fox News     general    -0.8252  negative  2023-10-19
# 45         TechRadar  technology    -0.5295  negative  2023-10-30
# 46          NBC News     general    -0.5513  negative  2023-10-20
# 47    Breitbart News     general     0.3316  positive  2023-10-27
# 48          Fox News     general     0.0000   neutral  2023-10-18
# 49          Engadget  technology    -0.6099  negative  2023-11-01
# 50           Reuters     general    -0.3458  negative  2023-10-24
# 51        TechCrunch  technology     0.0000   neutral  2023-10-15
# 52         USA Today     general    -0.6586  negative  2023-10-26
#
#                                                  text
# 0   In lithium-ion batteries, thats no longer the ...
# 1   Ford hits the brakes on $12 billion in EV spen...
# 2   Enlarge/ GreenPower has given its class-D elec...
# 3   Wuling Hongguang Mini EVs on display at the Sh...
# 4   In a big boost to sustainable mobility, 130 mi...
# 5   Norwegian tech company AutoStore today unveile...
# 6   When something enters Earth's atmosphere, it's...
# 7   Space isn't hard only on account of the rocket...
# 8   The National Spherical Torus Experiment-Upgrad...
# 9   In her new book, The Woman in Me, Britney Spea...
# 10  The rocky relationship between Britney Spears ...
# 11  Enlarge/ The back of the 2019 iPad Air.\r\n13 ...
# 12  Riders of Toos Elite 60-volt electric scooters...
# 13  Brian Wang is a Futurist Thought Leader and a ...
# 14  Passive cooling could be more efficient using ...
# 15  As e-scooters, hoverboards and e-bikes increas...
# 16  With the growing popularity of disposable e-ci...
# 17  Toyota will invest an additional $8 billion in...
# 18  Solid-state batteries could be lighter and mor...
# 19  Mercedes-Benz launched the series production v...
# 20  Remote Retriever via CBS Deals\r\nThis week on...
# 21  U.S. consumers are being strongly warned again...
# 22  RALEIGH, N.C. -- Toyota will invest an additio...
# 23  Since Russian President Vladimir Putin invaded...
# 24  The Taliban jihadist regime in Afghanistan sen...
# 25  Haji Nooruddin Azizi, the acting commerce mini...
# 26  TOKYO -- Toyotas July-September profit jumped ...
# 27  WASHINGTON -- With the growing popularity of d...
# 28  TOKYO -- Trade and economy officials from the ...
# 29  The Athel tamarisk has ingenious ways of survi...
# 30  Around the world, entrepreneurs are trying to ...
# 31  RALEIGH, N.C. -- Toyota will invest an additio...
# 32  TOKYO -- TOKYO (AP) We love battery EVs.\r\nTa...
# 33  WASHINGTON -- With the growing popularity of d...
# 34  TOKYO -- TOKYO (AP) We love battery EVs.\r\nTa...
# 35  TOKYO -- Toyotas July-September profit jumped ...
# 36  TOKYO -- Trade and economy officials from the ...
# 37  Britney Spears knows what it means to be depri...
# 38  TOKYO -- TOKYO (AP) We love battery EVs.\r\nTa...
# 39  BEIJING -- China is hosting its third internat...
# 40  Chiles far-left President Gabriel Boric met wi...
# 41  Enlarge/ A GM Ultium battery pack. \r\n75 with...
# 42  After investing billions to adhere to Presiden...
# 43  Nearly 7,000 auto workers at Stellantis’ Sterl...
# 44  With the growing popularity of disposable e-ci...
# 45  Yeedi Cube: One-minute review\r\nThe Yeedi Cub...
# 46  Britney Spears is shedding new light onto what...
# 47  After investing billions into a green energy a...
# 48  In yet another attempt to regulate the car mar...
# 49  Your EV may go a long way between charges, but...
# 50  DETROIT, Oct 24 (Reuters) - General Motors (GM...
# 51  Ten billion. That’s how many commercially proc...
# 52  More than a dozen states now have near-total a...

# %% [markdown]
# # Option 1

# %%
new_text=""

for index, row in df.iterrows():
    for character in df.at[index, 'text']:
        if character in string.printable:
            new_text+=character
    df.at[index, 'text'] = new_text
    new_text=""

# %%
#CONVERT FROM STRING LABELS TO INTEGERS 
labels=[]; #y1=[]; y2=[]
y1=[]
for label in df["label"]:
    if label not in labels:
        labels.append(label)
        print("index =",len(labels)-1,": label =",label)
    for i in range(0,len(labels)):
        if(label==labels[i]):
            y1.append(i)
y1=np.array(y1)

# CONVERT DF TO LIST OF STRINGS 
corpus=df["text"].to_list()
y2=df["sentiment"].to_numpy()

print("number of text chunks = ",len(corpus))
print(corpus[0:3])
# Out:
# index = 0 : label = negative
# index = 1 : label = positive
# index = 2 : label = neutral
# number of text chunks =  53
# ['In lithium-ion batteries, thats no longer the case. Modern batteries are capable of reading their state no matter their level of charge, and when your device isnt in use the strain on the battery is  [+3255 chars]', 'Ford hits the brakes on $12 billion in EV spending because EVs are too expensive\r\nFord hits the brakes on $12 billion in EV spending because EVs are too expensive\r\n / The car company says it isnt bac [+2216 chars]', 'Enlarge/ GreenPower has given its class-D electric school bus a big battery bump.\r\n39 with \r\nOn Tuesday morning, the West Virginia-based GreenPower Motor Company debuted its latest electric vehicle.  [+4366 chars]']

# %%
# INITIALIZE COUNT VECTORIZER
# minDF = 0.01 means "ignore terms that appear in less than 1% of the documents". 
# minDF = 5 means "ignore terms that appear in less than 5 documents".
vectorizer=CountVectorizer(min_df=0.0001)   

# RUN COUNT VECTORIZER ON OUR COURPUS 
Xs  =  vectorizer.fit_transform(corpus)   
X=np.array(Xs.todense())

#CONVERT TO ONE-HOT VECTORS
maxs=np.max(X,axis=0)
X=np.ceil(X/maxs)

# DOUBLE CHECK 
print(X.shape,y1.shape,y2.shape)
print("DATA POINT-0:",X[0,0:10],"y1 =",y1[0],"  y2 =",y2[0])

# %%
#INSERT CODE TO PARTITION DATASET INTO TRAINING-TEST
from sklearn.model_selection import train_test_split
test_ratio=0.2
x_train, x_test, y_train, y_test = train_test_split(X, y1, test_size=test_ratio, random_state=0)
y_train=y_train.flatten()
y_test=y_test.flatten()

print("x_train.shape		:",x_train.shape)
print("y_train.shape		:",y_train.shape)

print("X_test.shape		:",x_test.shape)
print("y_test.shape		:",y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/mariaagustinazuckerberg/Documents/Georgetown University/1. Fall 2023/DSAN 5000/dsan-5000-project-mazuckerberg-git/dsan-website/5000-website/4_1_NaiveBayes_R.ipynb Cell 7 line 4
#       <a href='vscode-notebook-cell:/Users/mariaagustinazuckerberg/Documents/Georgetown%20University/1.%20Fall%202023/DSAN%205000/dsan-5000-project-mazuckerberg-git/dsan-website/5000-website/4_1_NaiveBayes_R.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> from sklearn.model_selection import train_test_split
#       <a href='vscode-notebook-cell:/Users/mariaagustinazuckerberg/Documents/Georgetown%20University/1.%20Fall%202023/DSAN%205000/dsan-5000-project-mazuckerberg-git/dsan-website/5000-website/4_1_NaiveBayes_R.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> test_ratio=0.2
# ----> <a href='vscode-notebook-cell:/Users/mariaagustinazuckerberg/Documents/Georgetown%20University/1.%20Fall%202023/DSAN%205000/dsan-5000-project-mazuckerberg-git/dsan-website/5000-website/4_1_NaiveBayes_R.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> x_train, x_test, y_train, y_test = train_test_split(X, y1, test_size=test_ratio, random_state=0)
#       <a href='vscode-notebook-cell:/Users/mariaagustinazuckerberg/Documents/Georgetown%20University/1.%20Fall%202023/DSAN%205000/dsan-5000-project-mazuckerberg-git/dsan-website/5000-website/4_1_NaiveBayes_R.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> y_train=y_train.flatten()
#       <a href='vscode-notebook-cell:/Users/mariaagustinazuckerberg/Documents/Georgetown%20University/1.%20Fall%202023/DSAN%205000/dsan-5000-project-mazuckerberg-git/dsan-website/5000-website/4_1_NaiveBayes_R.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a> y_test=y_test.flatten()
#
# NameError: name 'X' is not defined

# %%
def report(y,ypred):
      #ACCURACY COMPUTE 
      print("Accuracy:",accuracy_score(y, ypred)*100)
      print("Number of mislabeled points out of a total %d points = %d"
            % (y.shape[0], (y != ypred).sum()))

def print_model_summary():
      # LABEL PREDICTIONS FOR TRAINING AND TEST SET 
      yp_train = model.predict(x_train)
      yp_test = model.predict(x_test)

      print("ACCURACY CALCULATION\n")

      print("TRAINING SET:")
      report(y_train,yp_train)

      print("\nTEST SET (UNTRAINED DATA):")
      report(y_test,yp_test)

      print("\nCHECK FIRST 20 PREDICTIONS")
      print("TRAINING SET:")
      print(y_train[0:20])
      print(yp_train[0:20])
      print("ERRORS:",yp_train[0:20]-y_train[0:20])

      print("\nTEST SET (UNTRAINED DATA):")
      print(y_test[0:20])
      print(yp_test[0:20])
      print("ERRORS:",yp_test[0:20]-y_test[0:20])

# %%
from sklearn.naive_bayes import MultinomialNB

# INITIALIZE MODEL 
model = MultinomialNB()

# TRAIN MODEL 
model.fit(x_train,y_train)

# PRINT REPORT USING UTILITY FUNCTION ABOVE
print_model_summary()

# %% [markdown]
# # Option 2

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import os
import shutil

#OUTPUT FOLDER: START FRESH (DELETE OLD ONE IF EXISTS)
output_dir = "output"
if os.path.exists(output_dir) and os.path.isdir(output_dir):
    shutil.rmtree(output_dir)
os.mkdir(output_dir)

# %%
print(df.shape)
print(df.columns)

# %%
reviews=[]
y=[]
#ITERATE OVER ROWS
# for i in range(0,10):  
for i in range(0,df.shape[0]):
    # QUICKLY CLEAN TEXT
    keep="abcdefghijklmnopqrstuvwxyz "
    replace=".,!;"
    tmp=""
    for char in df["text"][i].replace("<br />","").lower():
        if char in replace:
            tmp+=" "
        if char in keep:
            tmp+=char
    tmp=" ".join(tmp.split())
    reviews.append(tmp)
    # CONVERT STRINGS TO INT TAGS
    if(df["label"][i]=="positive"):
        y.append(1)
    if(df["label"][i]=="negative"):
        y.append(-1)
    if(df["label"][i]=="neutral"):
        y.append(0)

    #PRINT FIRST COUPLE REVIEWS
    if(i<3):
        print(i)
        print(df["text"][i].replace("<br />",""),'\n')
        print(tmp)
        print(df["label"][i],y[i])

# %%
y=np.array(y)

# %%
print(len(reviews),len(y))

# %%
from sklearn.feature_extraction.text import CountVectorizer

def vectorize(corpus,MAX_FEATURES):
    vectorizer=CountVectorizer(max_features=MAX_FEATURES,stop_words="english")   
    # RUN COUNT VECTORIZER ON OUR COURPUS 
    Xs  =  vectorizer.fit_transform(corpus)   
    X=np.array(Xs.todense())
    #CONVERT TO ONE-HOT VECTORS (can also be done with binary=true in CountVectorizer)
    maxs=np.max(X,axis=0)
    return (np.ceil(X/maxs),vectorizer.vocabulary_)

(x,vocab0)=vectorize(reviews,MAX_FEATURES=10000)

# %%
print(x.shape,y.shape)

# %%
#swap keys and values (value --> ley)
vocab1 = dict([(value, key) for key, value in vocab0.items()])

# %%
# CHECK VOCAB KEY-VALUE PAIRS
print(list(vocab1.keys())[0:10])
print(list(vocab1.values())[0:10])

# %%
# CHECK TO SEE IF COUNT-VECT COLUMNS ARE SORTED BY OCCURRENCE 
print(x.sum(axis=0))

# %%
#RE-ORDER COLUMN SO IT IS SORTED FROM HIGH FREQ TERMS TO LOW 
# https://stackoverflow.com/questions/60758625/sort-pandas-dataframe-by-sum-of-columns
df2=pd.DataFrame(x)
s = df2.sum(axis=0)
df2=df2[s.sort_values(ascending=False).index[:]]
print(df2.head())

# %%
# REMAP DICTIONARY TO CORRESPOND TO NEW COLUMN NUMBERS
print()
i1=0
vocab2={}
for i2 in list(df2.columns):
    # print(i2)
    vocab2[i1]=vocab1[int(i2)]
    i1+=1

#DOUBLE CHECK 
print(vocab2[0],vocab1[94])
print(vocab2[1],vocab1[186])

# %%
# RENAME COLUMNS 0,1,2,3 .. 
df2.columns = range(df2.columns.size)
print(df2.head())
print(df2.sum(axis=0))
x=df2.to_numpy()

# %%
# DOUBLE CHECK 
print(x.shape,y.shape)

# %%
import random
N=x.shape[0]
l = [*range(N)]     # indices
cut = int(0.8 * N) #80% of the list
random.shuffle(l)   # randomize
train_index = l[:cut] # first 80% of shuffled list
test_index = l[cut:] # last 20% of shuffled list

print(train_index[0:10])
print(test_index[0:10])

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
import time

def train_MNB_model(X,Y,i_print=False):

    if(i_print):
        print(X.shape,Y.shape)

    #SPLIT
    x_train=X[train_index]
    y_train=Y[train_index].flatten()

    x_test=X[test_index]
    y_test=Y[test_index].flatten()

    # INITIALIZE MODEL 
    model = MultinomialNB()

    # TRAIN MODEL 
    start = time.process_time()
    model.fit(x_train,y_train)
    time_train=time.process_time() - start

    # LABEL PREDICTIONS FOR TRAINING AND TEST SET 
    start = time.process_time()
    yp_train = model.predict(x_train)
    yp_test = model.predict(x_test)
    time_eval=time.process_time() - start

    acc_train= accuracy_score(y_train, yp_train)*100
    acc_test= accuracy_score(y_test, yp_test)*100

    if(i_print):
        print(acc_train,acc_test,time_train,time_eval)

    return (acc_train,acc_test,time_train,time_eval)


#TEST
print(type(x),type(y))
print(x.shape,y.shape)
(acc_train,acc_test,time_train,time_eval)=train_MNB_model(x,y,i_print=True)

# %%
def initialize_arrays():
    global num_features,train_accuracies
    global test_accuracies,train_time,eval_time
    num_features=[]
    train_accuracies=[]
    test_accuracies=[]
    train_time=[]
    eval_time=[]

# %%
# INITIALIZE ARRAYS
initialize_arrays()

# DEFINE SEARCH FUNCTION
def partial_grid_search(num_runs, min_index, max_index):
    for i in range(1, num_runs+1):
        # SUBSET FEATURES 
        upper_index=min_index+i*int((max_index-min_index)/num_runs)
        xtmp=x[:,0:upper_index]

        #TRAIN 
        (acc_train,acc_test,time_train,time_eval)=train_MNB_model(xtmp,y,i_print=False)

        if(i%5==0):
            print(i,upper_index,xtmp.shape[1],acc_train,acc_test)
            
        #RECORD 
        num_features.append(xtmp.shape[1])
        train_accuracies.append(acc_train)
        test_accuracies.append(acc_test)
        train_time.append(time_train)
        eval_time.append(time_eval)

# DENSE SEARCH (SMALL NUMBER OF FEATURES (FAST))
partial_grid_search(num_runs=100, min_index=0, max_index=1000)

# SPARSE SEARCH (LARGE NUMBER OF FEATURES (SLOWER))
partial_grid_search(num_runs=20, min_index=1000, max_index=10000)

# %%
def save_results(path_root):
    out=np.transpose(np.array([num_features,train_accuracies,test_accuracies,train_time,eval_time])) 
    out=pd.DataFrame(out)
    out.to_csv(path_root+".csv")

# %%
#UTILITY FUNCTION TO PLOT RESULTS
def plot_results(path_root):

    #PLOT-1
    plt.plot(num_features,train_accuracies,'-or')
    plt.plot(num_features,test_accuracies,'-ob')
    plt.xlabel('Number of features')
    plt.ylabel('ACCURACY: Training (blue) and Test (red)')
    plt.savefig(path_root+'-1.png')
    plt.show()

    # #PLOT-2
    plt.plot(num_features,train_time,'-or')
    plt.plot(num_features,eval_time,'-ob')
    plt.xlabel('Number of features')
    plt.ylabel('Runtime: training time (red) and evaluation time(blue)')
    plt.savefig(path_root+'-2.png')
    plt.show()

    # #PLOT-3
    plt.plot(np.array(test_accuracies),train_time,'-or')
    plt.plot(np.array(test_accuracies),eval_time,'-ob')
    plt.xlabel('test_accuracies')
    plt.ylabel('Runtime: training time (red) and evaluation time (blue)')
    plt.savefig(path_root+'-3.png')
    plt.show()

    # #PLOT-3
    plt.plot(num_features,np.array(train_accuracies)-np.array(test_accuracies),'-or')
    plt.xlabel('Number of features')
    plt.ylabel('train_accuracies-test_accuracies')
    plt.savefig(path_root+'-4.png')
    plt.show()

# %%
save_results(output_dir+"/partial_grid_search")
plot_results(output_dir+"/partial_grid_search")

# %%
x_var=np.var(x,axis=0)
print(np.min(x_var))
print(np.max(x_var))


from sklearn.feature_selection import VarianceThreshold

# DEFINE GRID OF THRESHOLDS 
num_thresholds=30
thresholds=np.linspace(np.min(x_var),np.max(x_var),num_thresholds)

#DOESN"T WORK WELL WITH EDGE VALUES 
thresholds=thresholds[1:-2]; #print(thresholds)

# INITIALIZE ARRAYS
initialize_arrays()

# SEARCH FOR OPTIMAL THRESHOLD
for THRESHOLD in thresholds:
    feature_selector = VarianceThreshold(threshold=THRESHOLD)
    xtmp=feature_selector.fit_transform(x)
    print("THRESHOLD =",THRESHOLD, xtmp.shape[1])

    (acc_train,acc_test,time_train,time_eval)=train_MNB_model(xtmp,y,i_print=False)
             
    #RECORD 
    num_features.append(xtmp.shape[1])
    train_accuracies.append(acc_train)
    test_accuracies.append(acc_test)
    train_time.append(time_train)
    eval_time.append(time_eval)

# %%
save_results(output_dir+"/variance_threshold")
plot_results(output_dir+"/variance_threshold")
