# %% [raw]
# ---
# title: "Data Gathering Python"
# ---

# %%
from datetime import date
from dateutil.relativedelta import relativedelta

# %% [markdown]
# ## Lithium News

# %%
from newsapi.newsapi_client import NewsApiClient
import pandas as pd

date = date.today()
date_past = date - relativedelta(day=10)

f = open('auth.k','r', encoding="utf-8")
ak = f.readlines()
f.close()

newsapi = NewsApiClient(api_key=ak[0])

sources = newsapi.get_sources()

sources = pd.DataFrame(sources['sources'])

sources = sources[(sources['language'] == 'en') & (sources['country'] == 'us') & ~sources['category'].isin(['sports', 'entertainment', 'health'])]


df_sources = ', '.join(sources['id'].astype(str))

df_domains = ', '.join(sources['url'].astype(str))

all_articles = newsapi.get_everything(q='lithium',
                                      sources=str(df_sources),
                                      domains=str(df_domains),
                                      from_param=date_past,
                                      to=date,
                                      language='en',
                                      sort_by='relevancy')

df_articles = pd.DataFrame(all_articles['articles'])

df_articles
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#                                                source  \
# 0      {'id': 'ars-technica', 'name': 'Ars Technica'}
# 1      {'id': 'ars-technica', 'name': 'Ars Technica'}
# 2              {'id': 'newsweek', 'name': 'Newsweek'}
# 3   {'id': 'breitbart-news', 'name': 'Breitbart Ne...
# 4              {'id': 'cbs-news', 'name': 'CBS News'}
# 5              {'id': 'cbs-news', 'name': 'CBS News'}
# 6              {'id': 'cbs-news', 'name': 'CBS News'}
# 7              {'id': 'newsweek', 'name': 'Newsweek'}
# 8              {'id': 'cbs-news', 'name': 'CBS News'}
# 9              {'id': 'cbs-news', 'name': 'CBS News'}
# 10           {'id': 'the-verge', 'name': 'The Verge'}
# 11           {'id': 'the-verge', 'name': 'The Verge'}
# 12               {'id': 'reuters', 'name': 'Reuters'}
# 13           {'id': 'the-verge', 'name': 'The Verge'}
# 14           {'id': 'the-verge', 'name': 'The Verge'}
#
#                              author  \
# 0                      Ryan Waniata
# 1                Jonathan M. Gitlin
# 2                      Anna Skinner
# 3          John Binder, John Binder
# 4                     Jason R. Rich
# 5                    Kaylyn McKenna
# 6                     Fox Van Allen
# 7                     Pandora Dewan
# 8                     Fox Van Allen
# 9   Jennifer Martin, Kaylyn McKenna
# 10          Antonio G. Di Benedetto
# 11                      Nilay Patel
# 12                          Reuters
# 13                    Justine Calma
# 14                      Dan Seifert
#
#                                                 title  \
# 0   25 of the most popular Amazon Prime Day deals ...
# 1   The 2023 Toyota Prius Prime is a mostly pleasa...
# 2            Rare Metal Discovery Gives China a Boost
# 3   Canadians Join UAW Strike as American Auto Wor...
# 4   Amazon is practically giving away Blink video ...
# 5   When is the next Amazon Prime Day after the Oc...
# 6   Our editors pick their favorite October Prime ...
# 7   Toys Top List of 10 Most Common Types of Elect...
# 8   The most popular Amazon October Prime Day 2023...
# 9   Nail down Amazon October Prime Day 2023 saving...
# 10       The best October Prime Day deals you can get
# 11  Rivian CEO RJ Scaringe on ramping up R1T produ...
# 12  Toyota, Idemitsu join hands to mass-produce al...
# 13  Vapes, chargers, and other ‘invisible’ e-waste...
# 14  The best October Prime Day deals available on ...
#
#                                           description  \
# 0   AirPods, docking stations, Switch games, and m...
# 1   Toyota has helpfully increased the size of the...
# 2   The find could widen China's lead in the elect...
# 3   Thousands of Canadian auto workers are joining...
# 4   You can get a Blink video doorbell for just $3...
# 5   Find out when you can expect the next Amazon P...
# 6   Not sure where to start at Amazon's October Pr...
# 7   Nearly $57 billion of rare metals and raw mate...
# 8   Looking for the best deals at Amazon's October...
# 9   Upgrade your toolshed for less with these Amaz...
# 10  Amazon’s Prime Big Deal Days is like the early...
# 11  RJ Scaringe sat down to discuss supply chain c...
# 12  Toyota Motor <a href="https://www.reuters.com/...
# 13  Chargers, vapes, and other small electronics m...
# 14  The final day of Prime Big Deal Days has arriv...
#
#                                                   url  \
# 0   https://arstechnica.com/shopping/2023/10/25-of...
# 1   https://arstechnica.com/cars/2023/10/the-2023-...
# 2   https://www.newsweek.com/rare-metal-discovery-...
# 3   https://www.breitbart.com/politics/2023/10/10/...
# 4   https://www.cbsnews.com/essentials/ring-in-50-...
# 5   https://www.cbsnews.com/essentials/when-is-the...
# 6   https://www.cbsnews.com/essentials/our-editors...
# 7   https://www.newsweek.com/toys-top-common-elect...
# 8   https://www.cbsnews.com/essentials/most-popula...
# 9   https://www.cbsnews.com/essentials/dewalt-ryob...
# 10  https://www.theverge.com/23905078/amazon-octob...
# 11  https://www.theverge.com/23908667/rivian-rj-sc...
# 12  https://www.reuters.com/business/autos-transpo...
# 13  https://www.theverge.com/2023/10/11/23912751/v...
# 14  https://www.theverge.com/2023/10/11/23912000/p...
#
#                                            urlToImage           publishedAt  \
# 0   https://cdn.arstechnica.net/wp-content/uploads...  2023-10-11T22:03:33Z
# 1   https://cdn.arstechnica.net/wp-content/uploads...  2023-10-11T16:47:27Z
# 2   https://d.newsweek.com/en/full/2293356/rare-me...  2023-10-11T16:56:55Z
# 3   https://media.breitbart.com/media/2023/10/Gett...  2023-10-10T19:21:20Z
# 4   https://assets3.cbsnewsstatic.com/hub/i/r/2023...  2023-10-10T11:25:08Z
# 5   https://assets2.cbsnewsstatic.com/hub/i/r/2023...  2023-10-11T16:24:00Z
# 6   https://assets3.cbsnewsstatic.com/hub/i/r/2023...  2023-10-11T03:03:49Z
# 7   https://d.newsweek.com/en/full/2292713/electro...  2023-10-11T23:01:01Z
# 8   https://assets2.cbsnewsstatic.com/hub/i/r/2023...  2023-10-11T13:50:04Z
# 9   https://assets3.cbsnewsstatic.com/hub/i/r/2023...  2023-10-10T14:04:28Z
# 10  https://cdn.vox-cdn.com/thumbor/DpR_IUCoiu2kau...  2023-10-10T12:00:43Z
# 11  https://cdn.vox-cdn.com/thumbor/L0OtJjmuMXKGW9...  2023-10-10T14:00:00Z
# 12  https://www.reuters.com/resizer/VW-QIBFgGOes6q...  2023-10-12T04:06:43Z
# 13  https://cdn.vox-cdn.com/thumbor/vonFLhBFKdRBiZ...  2023-10-11T23:01:00Z
# 14  https://cdn.vox-cdn.com/thumbor/AmecFMQlrbkXsV...  2023-10-11T11:58:57Z
#
#                                               content
# 0   Enlarge/ The case for AirPods Pro.\r\n5 with \...
# 1   Enlarge/ After a confusing mess for the last g...
# 2   Chinese scientists recently unearthed a rare o...
# 3   After thousands of Canadian auto workers joine...
# 4   Amazon\r\nDuring the Amazon Prime Big Deal Day...
# 5   Getty Images\r\nShould you shop now, or just w...
# 6   Amazon\r\nThe Amazon Prime Big Deal Days sale,...
# 7   Every year, 7.3 billion electronic toys are th...
# 8   Amazon\r\nThe Amazon Prime Big Deal Days sale,...
# 9   Amazon\r\nAmazon is offering some unbeatable t...
# 10  The best October Prime Day deals you can get\r...
# 11  Photo illustration by Alex Parkin / The Verge\...
# 12  TOKYO, Oct 12 (Reuters) - Toyota Motor (7203.T...
# 13  Vapes, chargers, and other invisible e-waste a...
# 14  Illustration by Lucia Pham / The Verge\r\n\n \...

# %%
sources
# Out:
#                             id                       name  \
# 0                     abc-news                   ABC News
# 3           al-jazeera-english         Al Jazeera English
# 6                 ars-technica               Ars Technica
# 8             associated-press           Associated Press
# 10                       axios                      Axios
# 16                   bloomberg                  Bloomberg
# 17              breitbart-news             Breitbart News
# 18            business-insider           Business Insider
# 22                    cbs-news                   CBS News
# 23                         cnn                        CNN
# 25           crypto-coins-news          Crypto Coins News
# 29                    engadget                   Engadget
# 36                     fortune                    Fortune
# 38                    fox-news                   Fox News
# 41                 google-news                Google News
# 55                 hacker-news                Hacker News
# 73                       msnbc                      MSNBC
# 76         national-geographic        National Geographic
# 77             national-review            National Review
# 78                    nbc-news                   NBC News
# 80               new-scientist              New Scientist
# 82                    newsweek                   Newsweek
# 83           new-york-magazine          New York Magazine
# 84             next-big-future            Next Big Future
# 88                    politico                   Politico
# 91                      recode                     Recode
# 92                reddit-r-all              Reddit /r/all
# 93                     reuters                    Reuters
# 102                 techcrunch                 TechCrunch
# 104                  techradar                  TechRadar
# 105  the-american-conservative  The American Conservative
# 107                   the-hill                   The Hill
# 109        the-huffington-post        The Huffington Post
# 113               the-next-web               The Next Web
# 116                  the-verge                  The Verge
# 117    the-wall-street-journal    The Wall Street Journal
# 118        the-washington-post        The Washington Post
# 119       the-washington-times       The Washington Times
# 120                       time                       Time
# 121                  usa-today                  USA Today
# 122                  vice-news                  Vice News
# 123                      wired                      Wired
#
#                                            description  \
# 0    Your trusted source for breaking news, analysi...
# 3    News, analysis from the Middle East and worldw...
# 6    The PC enthusiast's resource. Power users and ...
# 8    The AP delivers in-depth coverage on the inter...
# 10   Axios are a new media company delivering vital...
# 16   Bloomberg delivers business and markets news, ...
# 17   Syndicated news and opinion website providing ...
# 18   Business Insider is a fast-growing business si...
# 22   CBS News: dedicated to providing the best in j...
# 23   View the latest news and breaking news today f...
# 25   Providing breaking cryptocurrency news - focus...
# 29   Engadget is a web magazine with obsessive dail...
# 36        Fortune 500 Daily and Breaking Business News
# 38   Breaking News, Latest News and Current News fr...
# 41   Comprehensive, up-to-date news coverage, aggre...
# 55   Hacker News is a social news website focusing ...
# 73   Breaking news and in-depth analysis of the hea...
# 76   Reporting our world daily: original nature and...
# 77   National Review: Conservative News, Opinion, P...
# 78   Breaking news, videos, and the latest top stor...
# 80   Breaking science and technology news from arou...
# 82   Newsweek provides in-depth analysis, news and ...
# 83   NYMAG and New York magazine cover the new, the...
# 84   Coverage of science and technology that have t...
# 88   Political news about Congress, the White House...
# 91   Get the latest independent tech news, reviews ...
# 92   Reddit is an entertainment, social news networ...
# 93   Reuters.com brings you the latest news from ar...
# 102  TechCrunch is a leading technology media prope...
# 104  The latest technology news and reviews, coveri...
# 105  Realism and reform. A new voice for a new gene...
# 107  The Hill is a top US political website, read b...
# 109  The Huffington Post is a politically liberal A...
# 113  The Next Web is one of the world’s largest onl...
# 116  The Verge covers the intersection of technolog...
# 117  WSJ online coverage of breaking news and curre...
# 118  Breaking news and analysis on politics, busine...
# 119  The Washington Times delivers breaking news an...
# 120  Breaking news and analysis from TIME.com. Poli...
# 121  Get the latest national, international, and po...
# 122  Vice News is Vice Media, Inc.'s current affair...
# 123  Wired is a monthly American magazine, publishe...
#
#                                            url    category language country
# 0                       https://abcnews.go.com     general       en      us
# 3                     http://www.aljazeera.com     general       en      us
# 6                       http://arstechnica.com  technology       en      us
# 8                          https://apnews.com/     general       en      us
# 10                       https://www.axios.com     general       en      us
# 16                    http://www.bloomberg.com    business       en      us
# 17                    http://www.breitbart.com     general       en      us
# 18              http://www.businessinsider.com    business       en      us
# 22                      http://www.cbsnews.com     general       en      us
# 23                           http://us.cnn.com     general       en      us
# 25                         https://www.ccn.com  technology       en      us
# 29                    https://www.engadget.com  technology       en      us
# 36                          http://fortune.com    business       en      us
# 38                      http://www.foxnews.com     general       en      us
# 41                     https://news.google.com     general       en      us
# 55                https://news.ycombinator.com  technology       en      us
# 73                        http://www.msnbc.com     general       en      us
# 76          http://news.nationalgeographic.com     science       en      us
# 77             https://www.nationalreview.com/     general       en      us
# 78                      http://www.nbcnews.com     general       en      us
# 80   https://www.newscientist.com/section/news     science       en      us
# 82                    https://www.newsweek.com     general       en      us
# 83                            http://nymag.com     general       en      us
# 84               https://www.nextbigfuture.com     science       en      us
# 88                    https://www.politico.com     general       en      us
# 91                       http://www.recode.net  technology       en      us
# 92                https://www.reddit.com/r/all     general       en      us
# 93                      http://www.reuters.com     general       en      us
# 102                     https://techcrunch.com  technology       en      us
# 104                   http://www.techradar.com  technology       en      us
# 105    http://www.theamericanconservative.com/     general       en      us
# 107                         http://thehill.com     general       en      us
# 109              http://www.huffingtonpost.com     general       en      us
# 113                      http://thenextweb.com  technology       en      us
# 116                    http://www.theverge.com  technology       en      us
# 117                         http://www.wsj.com    business       en      us
# 118             https://www.washingtonpost.com     general       en      us
# 119           https://www.washingtontimes.com/     general       en      us
# 120                            http://time.com     general       en      us
# 121               http://www.usatoday.com/news     general       en      us
# 122                      https://news.vice.com     general       en      us
# 123                      https://www.wired.com  technology       en      us

# %% [markdown]
# ## IBM Watson - Sentiment Analysis

# %%
# pip install xlsxwriter
#pip install xlrd
#pip install openpyxl

import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, SentimentOptions

import os

# %%
df_content = pd.DataFrame(df_articles, columns=['source', 'content', 'publishedAt'])
df_content['source'] = df_content['source'].apply(lambda x: x['id'])

authenticator = IAMAuthenticator('_4YE1Qj6PFjke1zYsp7Kapgfu5laaaBE1E_ZUw1IiUPa')
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2020-08-01',
    authenticator=authenticator
)

natural_language_understanding.set_service_url('https://api.us-south.natural-language-understanding.watson.cloud.ibm.com/instances/8b0909d1-3768-4c54-b80d-b9817610e36d')

#IBM Watson
i = 0
ibm_source = []
ibm_date = []
ibm_score = []
ibm_label = []
for index, row in df_content.iterrows():
    response = natural_language_understanding.analyze(
    text=row['content'], language = 'en',
    features=Features(sentiment=SentimentOptions())).get_result()

    s = row['source']
    ibm_source.append(s)
    d = row['publishedAt']
    ibm_date.append(d)
    x = response['sentiment']['document']['score']
    x = round(x, 4)
    ibm_score.append(x)
    y = response['sentiment']['document']['label']
    ibm_label.append(y)
    # print(response['sentiment']['document']['score'])
    # print(response['sentiment']['document']['label'])
    # print(json.dumps(response, indent=2))

    i=i+1   

results = {"id": ibm_source, "ibm_date": ibm_date, "ibm_score": ibm_score, "ibm_label": ibm_label}

results = pd.DataFrame(data = results)

# %%
results = results.merge(sources, how='left')

results = pd.DataFrame(results, columns=['name', 'category', 'ibm_score', 'ibm_label', 'ibm_date'])

results = results.rename(columns={'ibm_date': 'date'})

results['date'] = pd.to_datetime(results['date'])

results['date'] = results['date'].dt.date

results
# Out:
#               name    category  ibm_score ibm_label        date
# 0     Ars Technica  technology    -0.8725  negative  2023-10-11
# 1     Ars Technica  technology     0.0000   neutral  2023-10-11
# 2         Newsweek     general     0.8858  positive  2023-10-11
# 3   Breitbart News     general     0.0000   neutral  2023-10-10
# 4         CBS News     general    -0.6413  negative  2023-10-10
# 5         CBS News     general    -0.9248  negative  2023-10-11
# 6         CBS News     general     0.0000   neutral  2023-10-11
# 7         Newsweek     general    -0.4266  negative  2023-10-11
# 8         CBS News     general     0.0000   neutral  2023-10-11
# 9         CBS News     general     0.7472  positive  2023-10-10
# 10       The Verge  technology     0.0000   neutral  2023-10-10
# 11       The Verge  technology     0.0000   neutral  2023-10-10
# 12         Reuters     general     0.0000   neutral  2023-10-12
# 13       The Verge  technology    -0.9079  negative  2023-10-11
# 14       The Verge  technology     0.3791  positive  2023-10-11
