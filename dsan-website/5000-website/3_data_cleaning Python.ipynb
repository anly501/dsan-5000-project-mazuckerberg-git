# %% [raw]
# ---
# title: "Data Gathering"
# ---

# %%
from datetime import date
from dateutil.relativedelta import relativedelta

# %% [markdown]
# ## Lithium News

# %%
from newsapi.newsapi_client import NewsApiClient
import pandas as pd

date = date.today()
date_past = date - relativedelta(months=1)

f = open('auth.k','r', encoding="utf-8")
ak = f.readlines()
f.close()

newsapi = NewsApiClient(api_key=ak[0])

sources = newsapi.get_sources()

sources = pd.DataFrame(sources['sources'])

sources = sources[(sources['language'] == 'en') & (sources['country'] == 'us') & ~sources['category'].isin(['sports', 'entertainment', 'health'])]


df_sources = ', '.join(sources['id'].astype(str))

df_domains = ', '.join(sources['url'].astype(str))

all_articles = newsapi.get_everything(q='lithium',
                                      sources=str(df_sources),
                                      domains=str(df_domains),
                                      from_param=date_past,
                                      to=date,
                                      language='en',
                                      sort_by='relevancy')

df_articles = pd.DataFrame(all_articles['articles'])

df_articles
# Out:
#                                                source  \
# 0            {'id': 'the-verge', 'name': 'The Verge'}
# 1      {'id': 'ars-technica', 'name': 'Ars Technica'}
# 2   {'id': 'business-insider', 'name': 'Business I...
# 3   {'id': 'business-insider', 'name': 'Business I...
# 4              {'id': 'engadget', 'name': 'Engadget'}
# ..                                                ...
# 95         {'id': 'techcrunch', 'name': 'TechCrunch'}
# 96             {'id': 'fox-news', 'name': 'Fox News'}
# 97             {'id': 'fox-news', 'name': 'Fox News'}
# 98               {'id': 'reuters', 'name': 'Reuters'}
# 99               {'id': 'reuters', 'name': 'Reuters'}
#
#                          author  \
# 0                 Justine Calma
# 1            Jonathan M. Gitlin
# 2                   Matthew Fox
# 3   Rebecca Cohen,Jessica Orwig
# 4                    Steve Dent
# ..                          ...
# 95                    Rita Liao
# 96             Thomas Catenacci
# 97             Thomas Catenacci
# 98                      Reuters
# 99                Belén Carreño
#
#                                                 title  \
# 0   The key ingredient to millions of EVs is burie...
# 1   Ford pauses work on $3.5 billion battery facto...
# 2   The world's largest deposit of lithium may hav...
# 3   Scientists found a massive lithium deposit ins...
# 4   Mercedes-Benz concept EV offers rapid charging...
# ..                                                ...
# 95  AquaLith might have an answer to the US batter...
# 96  House CCP panel probes Biden admin over Chines...
# 97  Dozens of Republicans probe US automaker for p...
# 98  China's Gotion to set up a $2 bln lithium batt...
# 99  Exclusive: EU may become as hooked on China ba...
#
#                                           description  \
# 0   The US holds one of the biggest known lithium ...
# 1   The site was going to make lithium iron phosph...
# 2   The study suggests that there could be 20 mill...
# 3   The new findings could translate to more than ...
# 4   Mercedes-Benz has unveiled its "close-to-produ...
# ..                                                ...
# 95  AquaLith looks to make new types of battery ce...
# 96  FIRST ON FOX: Republicans on the House Select ...
# 97  FIRST ON FOX: Republicans on the Energy and Co...
# 98  China's Gotion High-tech Co Ltd <a href="https...
# 99  The European Union could become as dependent o...
#
#                                                   url  \
# 0   https://www.theverge.com/2023/8/30/23849619/li...
# 1   https://arstechnica.com/cars/2023/09/ford-paus...
# 2   https://markets.businessinsider.com/news/commo...
# 3   https://www.businessinsider.com/massive-lithiu...
# 4   https://www.engadget.com/mercedes-benz-concept...
# ..                                                ...
# 95  https://techcrunch.com/2023/09/22/aqualith-mig...
# 96  https://www.foxnews.com/politics/house-ccp-pan...
# 97  https://www.foxnews.com/politics/dozens-republ...
# 98  https://www.reuters.com/business/autos-transpo...
# 99  https://www.reuters.com/business/energy/eu-may...
#
#                                            urlToImage           publishedAt  \
# 0   https://cdn.vox-cdn.com/thumbor/RvD3Z3TeMYZ0R4...  2023-08-30T19:43:11Z
# 1   https://cdn.arstechnica.net/wp-content/uploads...  2023-09-25T21:30:53Z
# 2   https://i.insider.com/65006686db12d30019065c55...  2023-09-12T15:19:36Z
# 3   https://i.insider.com/6501f50e992da60019eba736...  2023-09-14T03:11:54Z
# 4   https://s.yimg.com/ny/api/res/1.2/Tb3MdU6AywSR...  2023-09-04T07:58:00Z
# ..                                                ...                   ...
# 95  https://techcrunch.com/wp-content/uploads/2021...  2023-09-22T19:37:27Z
# 96  https://static.foxnews.com/foxnews.com/content...  2023-09-14T12:00:19Z
# 97  https://static.foxnews.com/foxnews.com/content...  2023-09-05T13:46:14Z
# 98  https://www.reuters.com/pf/resources/images/re...  2023-09-08T21:02:37Z
# 99  https://www.reuters.com/resizer/8-L6H-zKxlV5aT...  2023-09-17T19:31:59Z
#
#                                               content
# 0   The key ingredient to millions of EVs is burie...
# 1   Enlarge/ Ted Miller, manager of Ford Battery C...
# 2   Hafsteinn Karlsson / Getty Images\r\n<ul><li>T...
# 3   A general view shows the brine pools of Albema...
# 4   Mercedes-Benz has unveiled its "close-to-produ...
# ..                                                ...
# 95  AquaLith has its eye on a billion-dollar marke...
# 96  FIRST ON FOX: Republicans leaders on the House...
# 97  FIRST ON FOX: A group of 26 Republicans on the...
# 98  Sept 8 (Reuters) - China's Gotion High-tech Co...
# 99  MADRID, Sept 17 (Reuters) - The European Union...
#
# [100 rows x 8 columns]

# %%
sources
# Out:
#                             id                       name  \
# 0                     abc-news                   ABC News
# 3           al-jazeera-english         Al Jazeera English
# 6                 ars-technica               Ars Technica
# 8             associated-press           Associated Press
# 10                       axios                      Axios
# 16                   bloomberg                  Bloomberg
# 17              breitbart-news             Breitbart News
# 18            business-insider           Business Insider
# 22                    cbs-news                   CBS News
# 23                         cnn                        CNN
# 25           crypto-coins-news          Crypto Coins News
# 29                    engadget                   Engadget
# 36                     fortune                    Fortune
# 38                    fox-news                   Fox News
# 41                 google-news                Google News
# 55                 hacker-news                Hacker News
# 73                       msnbc                      MSNBC
# 76         national-geographic        National Geographic
# 77             national-review            National Review
# 78                    nbc-news                   NBC News
# 80               new-scientist              New Scientist
# 82                    newsweek                   Newsweek
# 83           new-york-magazine          New York Magazine
# 84             next-big-future            Next Big Future
# 88                    politico                   Politico
# 91                      recode                     Recode
# 92                reddit-r-all              Reddit /r/all
# 93                     reuters                    Reuters
# 102                 techcrunch                 TechCrunch
# 104                  techradar                  TechRadar
# 105  the-american-conservative  The American Conservative
# 107                   the-hill                   The Hill
# 109        the-huffington-post        The Huffington Post
# 113               the-next-web               The Next Web
# 116                  the-verge                  The Verge
# 117    the-wall-street-journal    The Wall Street Journal
# 118        the-washington-post        The Washington Post
# 119       the-washington-times       The Washington Times
# 120                       time                       Time
# 121                  usa-today                  USA Today
# 122                  vice-news                  Vice News
# 123                      wired                      Wired
#
#                                            description  \
# 0    Your trusted source for breaking news, analysi...
# 3    News, analysis from the Middle East and worldw...
# 6    The PC enthusiast's resource. Power users and ...
# 8    The AP delivers in-depth coverage on the inter...
# 10   Axios are a new media company delivering vital...
# 16   Bloomberg delivers business and markets news, ...
# 17   Syndicated news and opinion website providing ...
# 18   Business Insider is a fast-growing business si...
# 22   CBS News: dedicated to providing the best in j...
# 23   View the latest news and breaking news today f...
# 25   Providing breaking cryptocurrency news - focus...
# 29   Engadget is a web magazine with obsessive dail...
# 36        Fortune 500 Daily and Breaking Business News
# 38   Breaking News, Latest News and Current News fr...
# 41   Comprehensive, up-to-date news coverage, aggre...
# 55   Hacker News is a social news website focusing ...
# 73   Breaking news and in-depth analysis of the hea...
# 76   Reporting our world daily: original nature and...
# 77   National Review: Conservative News, Opinion, P...
# 78   Breaking news, videos, and the latest top stor...
# 80   Breaking science and technology news from arou...
# 82   Newsweek provides in-depth analysis, news and ...
# 83   NYMAG and New York magazine cover the new, the...
# 84   Coverage of science and technology that have t...
# 88   Political news about Congress, the White House...
# 91   Get the latest independent tech news, reviews ...
# 92   Reddit is an entertainment, social news networ...
# 93   Reuters.com brings you the latest news from ar...
# 102  TechCrunch is a leading technology media prope...
# 104  The latest technology news and reviews, coveri...
# 105  Realism and reform. A new voice for a new gene...
# 107  The Hill is a top US political website, read b...
# 109  The Huffington Post is a politically liberal A...
# 113  The Next Web is one of the world’s largest onl...
# 116  The Verge covers the intersection of technolog...
# 117  WSJ online coverage of breaking news and curre...
# 118  Breaking news and analysis on politics, busine...
# 119  The Washington Times delivers breaking news an...
# 120  Breaking news and analysis from TIME.com. Poli...
# 121  Get the latest national, international, and po...
# 122  Vice News is Vice Media, Inc.'s current affair...
# 123  Wired is a monthly American magazine, publishe...
#
#                                            url    category language country
# 0                       https://abcnews.go.com     general       en      us
# 3                     http://www.aljazeera.com     general       en      us
# 6                       http://arstechnica.com  technology       en      us
# 8                          https://apnews.com/     general       en      us
# 10                       https://www.axios.com     general       en      us
# 16                    http://www.bloomberg.com    business       en      us
# 17                    http://www.breitbart.com     general       en      us
# 18              http://www.businessinsider.com    business       en      us
# 22                      http://www.cbsnews.com     general       en      us
# 23                           http://us.cnn.com     general       en      us
# 25                         https://www.ccn.com  technology       en      us
# 29                    https://www.engadget.com  technology       en      us
# 36                          http://fortune.com    business       en      us
# 38                      http://www.foxnews.com     general       en      us
# 41                     https://news.google.com     general       en      us
# 55                https://news.ycombinator.com  technology       en      us
# 73                        http://www.msnbc.com     general       en      us
# 76          http://news.nationalgeographic.com     science       en      us
# 77             https://www.nationalreview.com/     general       en      us
# 78                      http://www.nbcnews.com     general       en      us
# 80   https://www.newscientist.com/section/news     science       en      us
# 82                    https://www.newsweek.com     general       en      us
# 83                            http://nymag.com     general       en      us
# 84               https://www.nextbigfuture.com     science       en      us
# 88                    https://www.politico.com     general       en      us
# 91                       http://www.recode.net  technology       en      us
# 92                https://www.reddit.com/r/all     general       en      us
# 93                      http://www.reuters.com     general       en      us
# 102                     https://techcrunch.com  technology       en      us
# 104                   http://www.techradar.com  technology       en      us
# 105    http://www.theamericanconservative.com/     general       en      us
# 107                         http://thehill.com     general       en      us
# 109              http://www.huffingtonpost.com     general       en      us
# 113                      http://thenextweb.com  technology       en      us
# 116                    http://www.theverge.com  technology       en      us
# 117                         http://www.wsj.com    business       en      us
# 118             https://www.washingtonpost.com     general       en      us
# 119           https://www.washingtontimes.com/     general       en      us
# 120                            http://time.com     general       en      us
# 121               http://www.usatoday.com/news     general       en      us
# 122                      https://news.vice.com     general       en      us
# 123                      https://www.wired.com  technology       en      us

# %% [markdown]
# ## IBM Watson - Sentiment Analysis

# %%
# pip install xlsxwriter
#pip install xlrd
#pip install openpyxl

import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, SentimentOptions

import os

# %%
df_content = pd.DataFrame(df_articles, columns=['source', 'content'])
df_content['source'] = df_content['source'].apply(lambda x: x['id'])

authenticator = IAMAuthenticator('_4YE1Qj6PFjke1zYsp7Kapgfu5laaaBE1E_ZUw1IiUPa')
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2020-08-01',
    authenticator=authenticator
)

natural_language_understanding.set_service_url('https://api.us-south.natural-language-understanding.watson.cloud.ibm.com/instances/8b0909d1-3768-4c54-b80d-b9817610e36d')

#IBM Watson
i = 0
ibm_source = []
ibm_score = []
ibm_label = []
for index, row in df_content.iterrows():
    response = natural_language_understanding.analyze(
    text=row['content'], language = 'en',
    features=Features(sentiment=SentimentOptions())).get_result()

    s = row['source']
    ibm_source.append(s)
    x = response['sentiment']['document']['score']
    x = round(x, 4)
    ibm_score.append(x)
    y = response['sentiment']['document']['label']
    ibm_label.append(y)
    #print(response['sentiment']['document']['score'])
    #print(response['sentiment']['document']['label'])
    #print(json.dumps(response, indent=2))

    i=i+1   

results = {"id": ibm_source, "ibm_score": ibm_score, "ibm_label": ibm_label}

results = pd.DataFrame(data = results)

# %%
date = date.today()
name = str(date) + '_results.csv'

results.to_csv(name, index=False)

results = results.merge(sources, how='left')

results = pd.DataFrame(results, columns=['name', 'category', 'ibm_score', 'ibm_label'])

results
# Out:
#                 name    category  ibm_score ibm_label
# 0          The Verge  technology    -0.5809  negative
# 1       Ars Technica  technology     0.0000   neutral
# 2   Business Insider    business    -0.6520  negative
# 3   Business Insider    business     0.7899  positive
# 4           Engadget  technology     0.0000   neutral
# ..               ...         ...        ...       ...
# 95        TechCrunch  technology    -0.5408  negative
# 96          Fox News     general     0.0000   neutral
# 97          Fox News     general    -0.3151  negative
# 98           Reuters     general     0.0000   neutral
# 99           Reuters     general    -0.5449  negative
#
# [100 rows x 4 columns]
